# %% [markdown]
# <a href="https://colab.research.google.com/github/BRama10/Support-Vector-Machines-Notebook/blob/main/ML_Support_Vector_Machines_%2B_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/coreyjwade/bca_datasets/master/diabetes.csv', nrows = 200)

df

X = df.iloc[:,:-1]
y=df.iloc[:,-1]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 195            5      158             84             41      210  39.4
# 196            1      105             58              0        0  24.3
# 197            3      107             62             13       48  22.9
# 198            4      109             64             44       99  34.8
# 199            4      148             60             27      318  30.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#arr (type = Dataframe) - A dataframe with > 1 rows and columns
#train (type = int, float) - Size of training dataset. If int, then specifies the integer length of the new dataset. If float, then specifies the fraction of arr to be returned.
#test (type = int, float) - Size of testing dataset. If int, then specifies the integer length of the new dataset. If float, then specifies the fraction of arr to be returned.
#predict (type = int, float) - Size of predicting dataset. If int, then specifies the integer length of the new dataset. If float, then specifies the fraction of arr to be returned.
#Note - type of train, test, predict must all be same. Ex. They all should be ints, or they all should be floats.

def df_split(arr, train, test, predict):
  try:
    arr_train = arr.sample(n=train)
    arr.drop(index=arr_train.index.tolist(), inplace = True)
    arr_test = arr.sample(n=test)
    arr.drop(index=arr_test.index.tolist(), inplace = True)
    arr_predict = arr
  except:
    num = len(arr)
    train1, test1, predict1 = int(num * train), int(num * test), int(num*predict)
    arr_train, arr_test, arr_predict = df_split(arr, train1, test1, predict1)
  finally:
    return arr_train, arr_test, arr_predict

# %%
train1, test1, predict1 = df_split(df,195,0,5)
train1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 165            6      104             74             18      156  29.9
# 96             2       92             62             28        0  31.6
# 106            1       96            122              0        0  22.4
# 124            0      113             76              0        0  33.3
# 88            15      136             70             32      110  37.1
# ..           ...      ...            ...            ...      ...   ...
# 62             5       44             62              0        0  25.0
# 27             1       97             66             15      140  23.2
# 190            3      111             62              0        0  22.6
# 66             0      109             88             30        0  32.5
# 85             2      110             74             29      125  32.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 165                     0.722   41        1
# ...

# %%
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score #ability of machine to find all positives
from sklearn.metrics import precision_score #ability of machine to correctly identify false positives
from sklearn.svm import SVC, SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import numpy
from sklearn.metrics import f1_score


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, train_size = 0.7, shuffle = True)

clf = SVC()
clf.fit(X_train, y_train)

scorer = make_scorer(f1_score, greater_is_better=True)
scores = cross_val_score(clf, X, y, scoring = scorer, cv=5)

numpy.mean(scores)
print(scores)
# Out:
# [0.725 0.7   0.675 0.675 0.825]

# %%
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score #ability of machine to find all positives
from sklearn.metrics import precision_score #ability of machine to correctly identify false positives
from sklearn.svm import SVC, SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import numpy
from sklearn.metrics import f1_score


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, train_size = 0.7)

clf = SVC()
clf.fit(X_train, y_train)

scorer = make_scorer(f1_score, greater_is_better=True)
scores = cross_val_score(clf, X, y, scoring = scorer, cv=5)

numpy.mean(scores)
print(scores)
# Out:
# [0.62068966 0.53846154 0.43478261 0.48       0.69565217]

# %% [markdown]
# F1_score = 2 * (precision * recall) / (precision + recall)

# %%
from sklearn.svm import SVC, SVR
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score #ability of machine to find all positives
from sklearn.metrics import precision_score #ability of machine to correctly identify false positives


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 268, train_size = 500)

clf = SVC()
clf.fit(X_train, y_train)
scorer = make_scorer(accuracy_score, normalize = False, greater_is_better=True)
cross_val_score(clf, X, y, scoring = scorer, cv=2)
val1 = accuracy_score(clf.predict(X_test), y_test, normalize = False)
val2 = accuracy_score(clf.predict(X_test), y_test, normalize = True)
print(val1, val2)
# Out:
# 197 0.7350746268656716

# %%
from xgboost import XGBClassifier, XGBRegressor

clf = XGBClassifier()

params = {
    'n_estimators' : [40,50,60,100],
    'max_depth' : [5],
    'subsample' : [0.5],
    'tree_method' : ['hist'],
    'booster' : ['gbtree'],
    'max_leaves' : [0],
    'max_bins' : [0],
    'grow_policy' : ['depthwise'],
    'learning_rate' : [0.1],
    'gamma' : [0],

}

scoring1 = {
    'prec' : 'precision',
    'rec' : 'recall',
    'acc1' : make_scorer(accuracy_score, normalize = False, greater_is_better=True),
    'acc2' : make_scorer(accuracy_score, normalize = True, greater_is_better=True)
}

grid = GridSearchCV(clf, param_grid = params, refit = 'precision', return_train_score = True)
grid.fit(X, y)
# Out:
# GridSearchCV(estimator=XGBClassifier(),
#              param_grid={'booster': ['gbtree'], 'gamma': [0],
#                          'grow_policy': ['depthwise'], 'learning_rate': [0.1],
#                          'max_bins': [0], 'max_depth': [5], 'max_leaves': [0],
#                          'n_estimators': [40], 'subsample': [0.5],
#                          'tree_method': ['hist']},
#              refit='precision', return_train_score=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 10)

clf1 = XGBClassifier(n_estimators = 40, max_depth = 5, subsample = 0.5, tree_method = 'hist', booster = 'gbtree', max_leaves = 0, max_bins = 0, grow_policy = 'depthwise', learning_rate = 0.3)
clf1.fit(X_train, y_train)
clf1.score(X_test, y_test)
# Out:
# 0.71875

# %%
grid.best_params_

# %%
grid.best_score_
# Out:
# 0.7787199728376198

# %%
import numpy as np

clf1= SVC(kernel = 'linear', C = 0.1)
for x in [0.1,0.07,0.05,0.03,0.01]:
  clf1= SVC(kernel = 'linear', C = x)
  print(np.mean(cross_val_score(clf1, X, y, cv=5)))
# Out:
# 0.7682794329853154
# 0.7682794329853154
# 0.7656820303879128
# 0.7669722434428318
# 0.7669807316866141

# %%
from sklearn.model_selection import GridSearchCV

scoring1 = {
    'prec' : 'precision',
    'rec' : 'recall',
    'acc1' : make_scorer(accuracy_score, normalize = False, greater_is_better=True),
    'acc2' : make_scorer(accuracy_score, normalize = True, greater_is_better=True)
}

params = {
    'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'C' : [0.1, 0.07, 0.05,0.03]
}

grid = GridSearchCV(clf, param_grid = params, return_train_score = True)
grid.fit(X, y)

# %%
#!pip install scikit-optimize
import skopt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.svm import SVC

print('skopt %s' % skopt.__version__)
# Out:
# skopt 0.9.0
